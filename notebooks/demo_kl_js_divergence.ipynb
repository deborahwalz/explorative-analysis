# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import sys
sys.path.append("../")

from functions import kl_divergence, js_divergence
from scipy.special import rel_entr

# %%
categories = ['first', 'second', 'third']
p = [0.10, 0.40, 0.50]
q = [0.80, 0.15, 0.05]

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,10))

ax[0].bar(events, p, label="Distribution p")
ax[1].bar(events, q, label="Distribution q")

for axis in ax:
    axis.legend()

plt.show()

# %%
kl_pq = kl_divergence(p, q)
print('KL(P || Q): %.3f bits' % kl_pq)

kl_qp = kl_divergence(q, p)
print('KL(Q || P): %.3f bits' % kl_qp)
# Out:
# KL(P || Q): 1.927 bits
# KL(Q || P): 2.022 bits

# %%
kl_pq = kl_divergence(p, q, base="log")
print('KL(P || Q): %.3f nats' % kl_pq)

kl_qp = kl_divergence(q, p, base="log")
print('KL(Q || P): %.3f nats' % kl_qp)
# Out:
# KL(P || Q): 1.336 nats
# KL(Q || P): 1.401 nats

# %% [markdown]
# ## Computing with SciPy:

# %%
kl_pq = rel_entr(p, q)
print('KL(P || Q): %.3f nats' % sum(kl_pq))

kl_qp = rel_entr(q, p)
print('KL(Q || P): %.3f nats' % sum(kl_qp))
# Out:
# KL(P || Q): 1.336 nats
# KL(Q || P): 1.401 nats
